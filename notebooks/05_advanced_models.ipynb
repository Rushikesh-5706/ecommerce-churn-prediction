# %% [markdown]
# # Model Training Pipeline
#
# This notebook executes the model training pipeline, including:
# 1.  **Data Loading**: Loading processed features.
# 2.  **Model Training**: Training baseline models (Logistic Regression, Random Forest, XGBoost, etc.).
# 3.  **Hyperparameter Tuning**: Optimizing model performance.
# 4.  **Ensemble Creation**: Stacking models for maximum predictive power.

# %%
import os
import sys

# Add src to path
sys.path.append(os.path.abspath('..'))

print("✓ Environment setup complete")
# Out:
# ✓ Environment setup complete

# %% [markdown]
# ## 1. Train Baseline Models

# %%
# !python3 ../src/05_train_models.py
# Out:
# ...
# TRAINING ALL MODELS
# ...
#
# ...
# LOADING PREPARED DATA
# ...
# Traceback (most recent call last):
#   File "/Users/rushikesh/Customer Churn Prediction System/notebooks/../src/05_train_models.py", line 316, in <module>
#     main()
#   File "/Users/rushikesh/Customer Churn Prediction System/notebooks/../src/05_train_models.py", line 254, in main
#     X_train, X_val, X_test, y_train, y_val, y_test = load_prepared_data()
#                                                      ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rushikesh/Customer Churn Prediction System/notebooks/../src/05_train_models.py", line 37, in load_prepared_data
#     X_train = pd.read_csv('data/processed/X_train.csv')
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# ## 2. Hyperparameter Tuning

# %%
# !python3 ../src/06_tune_models.py
# Out:
# ...
# HYPERPARAMETER TUNING
# ...
# Traceback (most recent call last):
#   File "/Users/rushikesh/Customer Churn Prediction System/notebooks/../src/06_tune_models.py", line 221, in <module>
#     main()
#   File "/Users/rushikesh/Customer Churn Prediction System/notebooks/../src/06_tune_models.py", line 162, in main
#     X_train, X_val, y_train, y_val = load_data()
#                                      ^^^^^^^^^^^
#   File "/Users/rushikesh/Customer Churn Prediction System/notebooks/../src/06_tune_models.py", line 23, in load_data
#     X_train = pd.read_csv('data/processed/X_train.csv')
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# ## 3. Create Stacking Ensemble

# %%
# !python3 ../src/07_create_ensemble.py
# Out:
# ...
# CREATING VOTING ENSEMBLE
# ...
# Traceback (most recent call last):
#   File "/Users/rushikesh/Customer Churn Prediction System/notebooks/../src/07_create_ensemble.py", line 112, in <module>
#     main()
#   File "/Users/rushikesh/Customer Churn Prediction System/notebooks/../src/07_create_ensemble.py", line 49, in main
#     X_val, y_val = load_data()
#                    ^^^^^^^^^^^
#   File "/Users/rushikesh/Customer Churn Prediction System/notebooks/../src/07_create_ensemble.py", line 15, in load_data
#     X_val = pd.read_csv('data/processed/X_val.csv')
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py", line 620, in _read
# ...
